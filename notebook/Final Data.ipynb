# %%
import os
import pandas as pd

# %%
os.getcwd()
# Out:
# 'C:\\Users\\2401-00010'

# %%
#df = pd.read_csv("D:\\Battery Management System\\FinalData\\data.csv")
pd.set_option('display.max_columns', None)
df.sample(5)
# Out:
#         CellVoltage(V)  PackVoltage(V)  ChargingCurrent(mA)  \
# 53572         4.692794        6.053304             5.629006
# 3456          4.834999        5.009480             3.838187
# 192005        6.633855        5.816068             4.672595
# 72239         4.238610        4.972661             5.265642
# 192710        2.055056        1.251517             4.762310
#
#         DischargeCurrent(mA)  Temperature(C)  CellTemperature(C)  \
# 53572               6.407563        4.962313            4.474210
# 3456                4.053074        5.488341            3.497529
# 192005              4.127873        5.993703            6.972011
# 72239               6.676672        4.823642            4.262520
# 192710              2.657942        3.979233            1.594625
#
#         AmbientTemp(C)  coolingSysTemp(C)  stateOfCharge(SOC)  \
# 53572         7.049549           6.065161            5.988384
# 3456          2.792698           3.873960            3.866009
# ...

# %%
df.columns
# Out:
# Index(['CellVoltage(V)', 'PackVoltage(V)', 'ChargingCurrent(mA)',
#        'DischargeCurrent(mA)', 'Temperature(C)', 'CellTemperature(C)',
#        'AmbientTemp(C)', 'coolingSysTemp(C)', 'stateOfCharge(SOC)',
#        'stateOfHealth(SOH)', 'stateOfPower(SOP)', 'internalResistance(ohm)',
#        'CycleCount', 'Velocity [km/h]', 'Elevation [m]', 'Throttle [%]',
#        'Motor Torque [Nm]', 'Longitudinal Acceleration [m/s^2]',
#        'Regenerative Braking Signal ', 'Battery Voltage [V]',
#        'Battery Current [A]', 'SoC', 'Route/Area', 'Weather', 'isAnomaly'],
#       dtype='object')

# %%
df.shape
# Out:
# (202137, 25)

# %%
round(df['isAnomaly'].value_counts()/len(df)*100,2)
# Out:
# isAnomaly
# 0.0    95.0
# 1.0     5.0
# Name: count, dtype: float64

# %%
df.isnull().sum()
# Out:
# CellVoltage(V)                          0
# PackVoltage(V)                          0
# ChargingCurrent(mA)                     0
# DischargeCurrent(mA)                    0
# Temperature(C)                          0
# CellTemperature(C)                      0
# AmbientTemp(C)                          0
# coolingSysTemp(C)                       0
# stateOfCharge(SOC)                      0
# stateOfHealth(SOH)                      0
# stateOfPower(SOP)                       0
# internalResistance(ohm)                 0
# CycleCount                              0
# Velocity [km/h]                      3012
# Elevation [m]                        3012
# Throttle [%]                         3012
# Motor Torque [Nm]                    3012
# Longitudinal Acceleration [m/s^2]    3012
# Regenerative Braking Signal          3012
# Battery Voltage [V]                  3012
# Battery Current [A]                  3012
# SoC                                  3012
# ...

# %%
sns.displot(df['CellVoltage(V)'])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.displot(df['PackVoltage(V)'])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.displot(df['ChargingCurrent(mA)'])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.displot(df['Temperature(C)'])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.displot(df['stateOfCharge(SOC)'])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.displot(df['Velocity [km/h]'])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.displot(df['Battery Current [A]'])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
